# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

df = pd.read_csv('datasets_19728_29747_WorldCupMatches.csv')

#Insepct datafram
print(df.head())
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
#creating a column that shows the total goals scored
#before we create the new column, we will look at the date type of the cloumns to ensure that the values are erither float or int

print(df.dtypes)
df['Total Goals'] = df['Home Team Goals'] + df['Away Team Goals']
# Out:
# Year                    float64
# Datetime                 object
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals         float64
# Away Team Goals         float64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals    float64
# Half-time Away Goals    float64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                 float64
# MatchID                 float64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %%
#creating a visualization of how many goals were scored each year the World Cup was held between 1930-2014


sns.set_style('whitegrid')
sns.set_context('poster',font_scale = .5)

#creating a figure and axes for my plot
plt.figure(figsize = [12,7])
ax = plt.subplot(1,1,1)
ax = sns.barplot(data = df, x = 'Year', y = 'Total Goals')

#getting rid of the .0 in the Year column in our database for formatting purpose
year_format = [1930 + x*4 for x in range(0,40)]
year_format.remove(1942)
year_format.remove(1946)
ax.set_xticklabels(year_format)

ax.set_title('Total Goals per Year')

plt.show()

# %%
#Creating a box plot to visualize the distribution of the goal data per year

df_goals = df[['Year','Total Goals']]
sns.set_context('notebook',font_scale = 1.25)

#creating figure and axes
plt.figure(figsize=[12,7])
ax1 = sns.boxplot(data = df_goals, x = 'Year', y = 'Total Goals', palette = 'Spectral')
ax1.set_xticklabels(year_format)
ax1.set_title('Goal Distribution per Year')

plt.show()
